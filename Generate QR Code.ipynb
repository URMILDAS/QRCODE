# %%
import qrcode
import matplotlib.pyplot as plt
data = "https://www.youtube.com/watch?v=UleaQtDCwwY"
filename = 'Manik.png'
image = qrcode.make(data)
image.save(filename)
plt.imshow(image, cmap = 'gray')
